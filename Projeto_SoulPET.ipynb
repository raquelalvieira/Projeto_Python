# %% [markdown]
# ## **PROJETO PYTHON GRUPO 4: PETSHOP**
# ## - Artur, Daiane, Gabriel e Raquel

# %% [markdown]
# ![Petshop Promoção e Divulgação - Cachorro Pet Post Instagram (Capa para Facebook) (500 px × 200 px).png](data:image/png;base64,...)

# %%
#CÓDIGO FINAL



#---> PRODUTOS

#HIGIENE
menu_higiene = ["Shampoo", "Condicionador", "Perfume"]

menu_shampoo = ["Shampoo Neutro", "Shampoo Espumante", "Shampoo de Coco", "Shampoo Especial"]
shampoo_preco = [31, 20, 21, 12]

menu_condicionador = ["Condicionador Premium", "Condicionador Hidratante", "Condicionador Neutro", "Condicionador Gold"]
condicionador_preco = [20, 17, 32, 15]

menu_perfume = ["Perfume Pompom", "Perfume Canela", "Perfume Madeira", "Perfume Bala"]
perfume_preco = [30, 15, 60, 11]


#RAÇÕES
menu_racao = ["Ração de Gato", "Ração de Cachorro", "Ração de Passaro", "Ração de Coelho"]
racao_preco = [12, 11, 9, 6]


#BRINQUEDOS
menu_brinquedo = ["Bolinha", "Osso", "Pelucia", "Sininho"]
brinquedo_preco = [12, 10, 11, 12]


# ---> SERVIÇOS
menu_servico = ["Banho", "Tosa", "Hotel", "SPA"]
servico_preco = [20, 30, 50, 100]


print('\033[033mOlá, Bem-Vindo a SoulPET !\033[m')
print('---------------------------------------------')

produto_db = []
servico_db = []
valor_servico_db = []
valor_produto_db = []
quantidade_servico_db = []
quantidade_produto_db = []
valor_quantidade_servico_db = []
valor_quantidade_produto_db = []
soma = []


while True:

  

  
  a = input(print('\033[034mInsira A para Acessar ou F para Finalizar:\033[m \n')) #Pagina1
  b = a.upper()


  if b == 'A':
    while True:

      #MENU PAGINA 1
      print("\nMENU PRINCIPAL\n--------------------")
      menu = int(input("Selecione uma opção: \n[0] - Produtos \n[1] - Serviços \n[2] - Carrinho de Compras \n[3] - Finalizar Programa\n"))

      if menu == 3:
        break

      if menu == 0: #PAGINA_PRODUTOS
        while True:
          print("\nPRODUTOS\n--------------------")
          menu = int(input("Selecione uma opção: \n[0] - Higiene \n[1] - Rações \n[2] - Brinquedos\n[3] - Voltar Menu Principal\n"))

          if menu == 3:
            break

          
          elif menu == 0: #PAGINA_HIGIENE
            print("\nPRODUTOS DE HIGIENE\n--------------------")
            menu = int(input(f"Selecione uma seção: \n[0] - {menu_higiene[0]} \n[1] - {menu_higiene[1]} \n[2] - {menu_higiene[2]}\n"))


###############################################################################

            while menu == 0: #PAGINA_SHAMPOO

              print("\nSEÇÃO DE SHMAPOO\n--------------------")
              menu = int(input(f"Selecione uma opção de Shampoo: \n[0] - {menu_shampoo[0]} R$- {shampoo_preco[0]:.2F} \n[1] - {menu_shampoo[1]} R$- {shampoo_preco[1]:.2F} \n[2] - {menu_shampoo[2]} R$- {shampoo_preco[2]:.2F} \n[3] - {menu_shampoo[3]} R$- {shampoo_preco[3]:.2F} \n[4] - Voltar\n"))
              if menu == 4:
                break
              
              produto_db.append(menu_shampoo[menu])
              valor_produto_db.append(shampoo_preco[menu])

              quantidade = int(input(f"\nInsira a Quantidade de Itens: \n"))
              quantidade_produto_db.append(quantidade)
              mult = quantidade * shampoo_preco[menu]
              valor_quantidade_produto_db.append(mult)
              
              mov = input(f"\nC - Continuar Compra \nV - Voltar Menu Principal \n") #MOV_PAGINA_SHAMPOO
              a = mov.upper()

              if a == 'C':
                i = 0
                for i in range(len(produto_db)):
                  print(f"\nProduto: {produto_db[i]} | x{quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
                  i += 1
            
                  if i == len(valor_quantidade_produto_db):
                    soma = sum(valor_quantidade_produto_db)
                    print(f"\nValor Final: R$ {soma:.2f}\n")
                    break #PAGINA_SHAMPOO  
              elif a == 'V':
                break                  

##############################################################################

            while menu == 1: #PAGINA_CONDICIONADOR

              print("\nSEÇÃO DE CONDICIONADOR\n--------------------")
              menu = int(input(f"Selecione uma opção de Condicionador: \n[0] - {menu_condicionador[0]} R$- {condicionador_preco[0]:.2f} \n[1] - {menu_condicionador[1]} R$- {condicionador_preco[1]:.2f} \n[2] - {menu_condicionador[2]} R$- {condicionador_preco[2]:.2f} \n[3] - {menu_condicionador[3]} R$- {condicionador_preco[3]:.2f} \n[4]- Voltar\n"))
              if menu == 4:
                break
              
              produto_db.append(menu_condicionador[menu])
              valor_produto_db.append(condicionador_preco[menu])

              quantidade = int(input(f"\nInsira a Quantidade de Itens: \n"))
              quantidade_produto_db.append(quantidade)
              mult = quantidade * condicionador_preco[menu]
              valor_quantidade_produto_db.append(mult)
              
              mov = input(f"\nC - Continuar Compra \nV - Voltar Menu Principal \nn") #MOV_PAGINA_CONDICIONADOR
              a = mov.upper()

              if a == 'C':
                i = 0
                for i in range(len(produto_db)):
                  print(f"\nProduto: {produto_db[i]} | x{quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
                  i += 1
            
                  if i == len(valor_quantidade_produto_db):
                    soma = sum(valor_quantidade_produto_db)
                    print(f"\nValor Final: R$ {soma:.2f}\n")
                    break #PAGINA_CONDICIONADOR
              elif a == 'V':
                break

################################################################################

            while menu == 2: #PAGINA_PERFUME

              print("\nSEÇÃO DE PERFUME\n--------------------")
              menu = int(input(f"Selecione uma opção de Perfume: \n[0] - {menu_perfume[0]} R$- {perfume_preco[0]:.2f} \n[1] - {menu_perfume[1]} R$- {perfume_preco[1]:.2f} \n[2] - {menu_perfume[2]} R$- {perfume_preco[2]:.2f} \n[3] - {menu_perfume[3]} R$- {perfume_preco[3]:.2f} \n[4] - Voltar\n"))
              if menu == 4:
                break

              produto_db.append(menu_perfume[menu])
              valor_produto_db.append(perfume_preco[menu])

              quantidade = int(input(f"\nInsira a Quantidade de Itens: \n"))
              quantidade_produto_db.append(quantidade)
              mult = quantidade * perfume_preco[menu]
              valor_quantidade_produto_db.append(mult)
              
              mov = input(f"\nC - Continuar Compra \nV - Voltar Menu Principal \n") #MOV_PAGINA_PERFUME
              a = mov.upper()

              if a == 'C':
                i = 0
                for i in range(len(produto_db)):
                  print(f"\nProduto: {produto_db[i]} | x{quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
                  i += 1
            
                  if i == len(valor_quantidade_produto_db):
                    soma = sum(valor_quantidade_produto_db)
                    print(f"\nValor Final: R$ {soma:.2f}\n")
                    break #PAGINA_PERFUME
              elif a == 'V':
                break

################################################################################
  

          elif menu == 1: #RAÇÕES
            menu = int(input(f"\nO tipo de ração: \n[0] - {menu_racao[0]} R$- {racao_preco[0]:.2f} \n[1] - {menu_racao[1]} R$- {racao_preco[1]:.2f}\n[2] - {menu_racao[2]} R$- {racao_preco[2]:.2f}\n[3] - {menu_racao[3]} R$- {racao_preco[3]:.2f} \n[4] - Voltar\n"))
            if menu == 4:
                break

            produto_db.append(menu_racao[menu])
            valor_produto_db.append(racao_preco[0])

            quantidade = int(input(f"\nInsira quantos Kg Deseja: \n"))
            quantidade_produto_db.append(quantidade)
            mult = quantidade * racao_preco[menu]
            valor_quantidade_produto_db.append(mult)
              
            mov = input(f"\nC - Continuar Compra \nV - Voltar Menu Principal \n") #MOV_PAGINA_RAÇÃO
            a = mov.upper()

            if a == 'C':
              i = 0
              for i in range(len(produto_db)):
                print(f"\nProduto: {produto_db[i]} | x{quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
                i += 1
            
                if i == len(valor_quantidade_produto_db):
                  soma = sum(valor_quantidade_produto_db)
                  print(f"\nValor Final: R$ {soma:.2f}\n")
                  break #PAGINA_RAÇÕES
            elif a == 'V':
              break

###############################################################################
 
          elif menu == 2: #PAGINA_BRINQUEDOS
            print("\nSEÇÃO DE BRINQUEDOS\n--------------------")
            menu = int(input(f"Selecione uma opção de Brinquedo: \n[0] - {menu_brinquedo[0]} R$- {brinquedo_preco[0]:.2f} \n[1] - {menu_brinquedo[1]} R$- {brinquedo_preco[1]:.2f} \n[2] - {menu_brinquedo[2]} R$- {brinquedo_preco[2]:.2f} \n[3] - {menu_brinquedo[3]} R$- {brinquedo_preco[3]:.2f} \n[4]- Voltar\n"))
            
            if menu == 4:
              break

            produto_db.append(menu_brinquedo [menu])
            valor_produto_db.append(brinquedo_preco[menu])

            quantidade = int(input(f"\nInsira a Quantidade de Itens: \n"))
            quantidade_produto_db.append(quantidade)
            mult = quantidade * brinquedo_preco[menu]
            valor_quantidade_produto_db.append(mult)

            mov = input(f"\nC - Continuar Compra \nV - Voltar Menu Principal \n") #MOV_PAGINA_BRINQUEDOS
            a = mov.upper()

            if a == 'C':
              i = 0
              for i in range(len(produto_db)):
                print(f"\nProduto: {produto_db[i]} | x{quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
                i += 1
            
                if i == len(valor_quantidade_produto_db):
                  soma = sum(valor_quantidade_produto_db)
                  print(f"\nValor Final: R$ {soma:.2f}\n")
                  break #PAGINA_BRINQUEDOS
            elif a == 'V':
              break

###############################################################################

      elif menu == 1: #PAGINA_SERVIÇOS
        while True:
          print("\nSEÇÃO SERVIÇOS\n--------------------")
          menu = int(input(f"Selecione uma opção de Serviço: \n[0] - {menu_servico[0]} - R${servico_preco[0]:.2f} \n[1] - {menu_servico[1]} - R${servico_preco[1]:.2f}\n[2] - {menu_servico[2]} - R${servico_preco[2]:.2f}\n[3] - {menu_servico[3]} - R${servico_preco[3]:.2f} \n[4] - Voltar\n"))
          
          if menu == 4:
            break
          
          servico_db.append(menu_servico[menu])
          valor_servico_db.append(servico_preco[menu])

          quantidade = int(input("\nInsira a quantidade: \n"))
          quantidade_servico_db.append(quantidade)
          mult = quantidade * servico_preco[menu]
          valor_quantidade_servico_db.append(mult)

          mov = input(f"\nC - Continuar Compra \nV - Voltar Menu Principal \n")
          a = mov.upper()

          if a == 'C':
            i = 0
            for i in range(len(servico_db)):
              print(f"\nServiço: {servico_db[i]} | x{quantidade_servico_db[i]} | Valor Total: R$ {valor_quantidade_servico_db[i]:.2f}")
              i += 1
            
              if i == len(valor_quantidade_servico_db):
                soma = sum(valor_quantidade_servico_db)
                print(f"\nValor Final: R$ {soma:.2f}\n")
                break #PAGINA_SERVICO

          elif a == 'V':
            break


################################################################################
 
      if menu == 2:  #CARRINHO
        i = 0
        for i in range(len(servico_db)):
          print(f"\nServiço: {servico_db[i]} | Quant. {quantidade_servico_db[i]} | Valor Total: R$ {valor_quantidade_servico_db[i]:.2f}")
          i += 1
            
          if i == len(valor_quantidade_servico_db):          
            break

        i = 0
        for i in range(len(produto_db)):
          print(f"\nProduto: {produto_db[i]} | Quant. {quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
          i += 1
            
          if i == len(valor_quantidade_produto_db):
            break

        soma = sum(valor_quantidade_servico_db) + sum(valor_quantidade_produto_db) 
        print(f"\nValor TOTAL da Compra: R$ {soma:.2f}\n")

        menu = int(input(print('\n\033[032m[0] - Finalizar Compra\033[m \n[1] - Voltar para Compra \n[2] - Cancelar Compra\n')))

        if menu == 0:
          forma_de_pagamento = int(input("\n[1] - Dinheiro \n[2] - Pix \n[3] - Cartão \nSelecione uma opção: \n"))

          if forma_de_pagamento == 1:

            valor = int(input("Insira  Valor Pago Pelo Cliente: \n")) 
            troco = valor - soma

            if troco >= 0:
              troco = troco

              notas50 = int(troco) // 50
              sobra1 = int (troco) % 50

              notas20 = sobra1 // 20
              sobra2 = sobra1 % 20

              notas10 = sobra2 // 10
              sobra3 = sobra2 % 10

              notas5 = sobra3 // 5
              sobra4 = sobra3 % 5

              notas2 = sobra4 // 2
              sobra5 = sobra4 % 2

              sobra5 = sobra5 % 2

              print(f"Valor Pago: R$ {valor:.2f}")
              print(f"Troco: R$ {troco:.2f}")
              print(f"notas de R$ 50 = {notas50} cédula")
              print(f"notas de R$ 20 = {notas20} cédula")
              print(f"notas de R$ 10 = {notas10} cédula")
              print(f"notas de R$ 5  = {notas5}  cédula")
              print(f"notas de R$ 2  = {notas2}  cédula")
              print(f"notas de R$ 1  = {sobra5}  cédula\n\n")

              print('\033[33mA SoulPET Agradece sua Visita !\033[m')
   
              break        
            else:
              print("Valor Insuficiente")
      
          elif forma_de_pagamento == 2:
            soma = sum(valor_quantidade_servico_db) + sum(valor_quantidade_produto_db)
            print(f"Valor Total:{soma} \nChave PIX:000-000-000")
            print('\033[33mA SoulPET Agradece sua Visita !\033[m')
 
            break

          elif forma_de_pagamento == 3:
            soma = sum(valor_quantidade_servico_db) + sum(valor_quantidade_produto_db)
            print(f'Valor Total:{soma} \nInsira ou Aproxime Cartão: ')
            print('\033[33mA SoulPEt Agradece sua Visita !\033[m')
             
            break

        elif menu == 2:
            print(f"\nOs itens da sua lista são:")
            
            i = 0
            for i in range(len(servico_db)):
              print(f"\nServiços: {servico_db[i]} | Quant. {quantidade_servico_db[i]} | Valor Total: R$ {valor_quantidade_servico_db[i]:.2f}")
              i += 1
            
              if i == len(valor_quantidade_servico_db):           
                break

            i = 0
            for i in range(len(produto_db)):
              print(f"Produto: {produto_db[i]} | Quant. {quantidade_produto_db[i]} | Valor Total: R$ {valor_quantidade_produto_db[i]:.2f}")
              i += 1
            
              if i == len(valor_quantidade_produto_db):
                break
            decisao = int(input(f"\nRealmente Deseja Cancelar a Compra?\n \n[0] - SIM \n[1] - NÃO \n"))
            if decisao == 0:           
              print('\033[33mA SoulPET Agradece sua visita\033[m')

              break        
        
  elif b == 'F': #Pagina1
   print('\033[33m Volte Sempre !\n"SoulPET um negócio com Alma de Bicho" \033[m')
   break

else: #Inicio
  print("Insira Valor Válido:")
# Out:
# Olá, Bem-Vindo a SoulPET !
# ---------------------------------------------
# Insira A para Acessar ou F para Finalizar:
#
# a
#
# MENU PRINCIPAL
# --------------------
# Selecione uma opção:
# [0] - Produtos
# [1] - Serviços
# [2] - Carrinho de Compras
# [3] - Finalizar Programa
# 0
#
# PRODUTOS
# --------------------
# Selecione uma opção:
# [0] - Higiene
# [1] - Rações
# [2] - Brinquedos
# [3] - Voltar Menu Principal
# 0
#
# PRODUTOS DE HIGIENE
# --------------------
# Selecione uma seção:
# [0] - Shampoo
# [1] - Condicionador
# [2] - Perfume
# 0
#
# SEÇÃO DE SHMAPOO
# --------------------
# Selecione uma opção de Shampoo:
# [0] - Shampoo Neutro R$- 31.00
# [1] - Shampoo Espumante R$- 20.00
# [2] - Shampoo de Coco R$- 21.00
# [3] - Shampoo Especial R$- 12.00
# [4] - Voltar
# 1
#
# Insira a Quantidade de Itens:
# 4
#
# C - Continuar Compra
# V - Voltar Menu Principal
# v
#
# SEÇÃO DE CONDICIONADOR
# --------------------
# Selecione uma opção de Condicionador:
# ...
